# %%
import print_info as prinf
import numpy as np

# FIRST CHOOSE FILTERS

# Currently there are three filter possibilities:
#   1. selecting level of play (pools/bracket/top8)
#   2. omitting a set of players from the query
#   3. selecting specific players for individual stats

# [1] LEVEL OF PLAY
# These numbers determine what games (e.g. pools, top32, winners finals) to include.
# To include all games, leave as [0,9]
level_limits = [1,9]
# Change the numbers to match your desired filter as follows:
# [0,9] includes all games from pools to grand finals ("gf2")
# [0,0] includes just pools games
# [5,5] includes just top8 games (but not wf, lf, or gf)
# [2,3] includes all top64 and top32 games (but not top16 or top8 games)
# 'pools'    = 0
# 'bracket'  = 1
# 'top64'    = 2
# 'top32'    = 3
# 'top16'    = 4
# 'top8'     = 5
# 'lf'       = 6
# 'wf'       = 7
# 'gf'       = 8
# 'gf2'      = 9

# [2] SKIP PLAYERS
# Any name included will be skipped during the query
skip_these_players = {
    'isai':1
    #'alvin':1,
    #'superboomfan':1
    }


# [3] INDIVIDUAL STATS
# print stats for each player in this list:
individual_stats = [
    'polarbair',
    'reckless'
    #'hungrybox'
    #'isai',
    #'superboomfan',
    #'tacos',
    #'alvin',
    #'revan',
    #'ld',
    #'dext3r'
    ]

# [4] Markdown_table or html readable?
markdown_flag = True


# PRINT QUERY RESULTS
prinf.print_smash_stats( level_limits, skip_these_players, individual_stats, markdown_flag )
# Out:
# SMASH ARCHIVE QUERY RESULTS
#
# from recorded games at the following events:
# 		2016 genesis 3
# 		2016 pound
# 		2016 goml
# 		2016 snosa2
# 		2017 beast7
# 		2016 ssc
# 		2017 genesis 4
# 		2016 shine
# 		2016 apex
# 		2016 summit
# 		2016 superboomed
# 		2016 bossbattle2
# 		2016 dpotg
#
# Skipping these players:
# 		isai
# Includes bracket games through gf2
# Number of players in query: 103
# Number of games in query: 846
#
#
# MATCHUP PERCENTAGES
#
#  | char1 | char2 | # games | % win char1 |
#  |:---|:---|---:|---:|
# |pika|pika|212.0|0.50|
# |kirby|pika|121.0|0.48|
# |yoshi|pika|113.0|0.48|
# |falcon|pika|93.0|0.48|
# |yoshi|kirby|45.0|0.20|
# |yoshi|falcon|38.0|0.50|
# |fox|pika|33.0|0.18|
# |fox|falcon|32.0|0.59|
# |pika|puff|30.0|0.53|
# |falcon|kirby|29.0|0.24|
# |falcon|falcon|28.0|0.50|
# |yoshi|fox|17.0|0.47|
# |kirby|kirby|16.0|0.50|
# |fox|kirby|14.0|0.57|
# |pika|mario|14.0|0.71|
# |falcon|mario|13.0|0.62|
# |kirby|puff|11.0|0.64|
# |pika|ness|9.0|0.78|
# |kirby|samus|8.0|0.62|
# |fox|fox|8.0|0.50|
# |dk|dk|8.0|0.50|
# |falcon|puff|7.0|0.71|
# |yoshi|dk|7.0|0.43|
# |yoshi|yoshi|6.0|0.50|
# |falcon|samus|5.0|0.80|
# |yoshi|puff|5.0|0.00|
# |fox|puff|5.0|1.00|
# |kirby|link|5.0|0.80|
# |falcon|ness|4.0|0.25|
# |pika|link|4.0|0.75|
# |fox|mario|4.0|0.25|
# |samus|samus|4.0|0.50|
# |falcon|link|4.0|1.00|
# |mario|luigi|4.0|0.75|
# |kirby|mario|3.0|0.33|
# |yoshi|ness|3.0|0.33|
# |puff|mario|3.0|1.00|
# |falcon|dk|3.0|0.67|
# |link|link|2.0|0.50|
# |ness|mario|2.0|0.50|
# |yoshi|link|2.0|1.00|
# |fox|ness|2.0|0.00|
# |kirby|ness|2.0|0.50|
# |kirby|luigi|2.0|0.50|
# |pika|samus|2.0|0.50|
# |pika|dk|2.0|0.50|
# |fox|dk|1.0|1.00|
# |mario|dk|1.0|1.00|
# |puff|samus|1.0|0.00|
# |kirby|dk|1.0|1.00|
#
# CHARACTER-BASED GAMES
# (excludes dittos)
# char		# games		% wins
# pika		421.0		0.56
# kirby		241.0		0.59
# yoshi		230.0		0.42
# falcon		228.0		0.47
# fox		108.0		0.45
# puff		62.0		0.45
# mario		44.0		0.43
# ness		22.0		0.50
# samus		16.0		0.38
# dk		15.0		0.40
# link		15.0		0.13
# luigi		6.0		0.33
#
# Total games 846.0 (two characters appear per game)
# char		# appearances	% of total
# pika		633.0		0.37
# kirby		257.0		0.15
# falcon		256.0		0.15
# yoshi		236.0		0.14
# fox		116.0		0.07
# puff		62.0		0.04
# mario		44.0		0.03
# dk		23.0		0.01
# ness		22.0		0.01
# samus		20.0		0.01
# link		17.0		0.01
# luigi		6.0		0.00
#
# Player-character game data
#
# player-character		# games		# wins		% win
# alvin-falcon        		19		13		0.68
# alvin-pika          		36		23		0.64
# banze-kirby         		1		0		0.00
# banze-pika          		3		0		0.00
# barksanchez-falcon  		3		3		1.00
# barksanchez-mario   		4		3		0.75
# barksanchez-pika    		105		55		0.52
# bon-pika            		4		1		0.25
# bonerstorm-puff     		1		0		0.00
# bonerstorm-yoshi    		1		0		0.00
# bonobono-yoshi      		5		1		0.20
# bp-yoshi            		5		1		0.20
# captainfabulous-falcon		2		0		0.00
# captainl-fox        		4		1		0.25
# clubbadubba-falcon  		3		2		0.67
# clubbadubba-pika    		8		4		0.50
# cobr-falcon         		6		6		1.00
# cobr-kirby          		6		4		0.67
# cobr-samus          		5		3		0.60
# comboblaze-falcon   		12		5		0.42
# connor-pika         		8		4		0.50
# ctg-puff            		14		5		0.36
# d35-pika            		3		1		0.33
# daniel-falcon       		3		1		0.33
# daniel-pika         		2		2		1.00
# darkgentleman-puff  		2		2		1.00
# darkhorse-falcon    		2		2		1.00
# darkhorse-puff      		2		0		0.00
# derek-pika          		14		8		0.57
# dext3r-pika         		34		16		0.47
# dfx-falcon          		5		3		0.60
# dfx-fox             		6		3		0.50
# dfx-pika            		1		0		0.00
# dount-fox           		2		2		1.00
# dtan-kirby          		18		10		0.56
# fckvwls-falcon      		4		2		0.50
# fireblaster-mario   		8		6		0.75
# fireblaster-pika    		1		0		0.00
# fireblaster-yoshi   		62		24		0.39
# firo-falcon         		2		1		0.50
# firo-link           		9		2		0.22
# firo-ness           		19		10		0.53
# firo-yoshi          		1		0		0.00
# fishamanp-falcon    		3		0		0.00
# freean-falcon       		2		1		0.50
# freean-luigi        		1		0		0.00
# fruity-mario        		5		0		0.00
# fumbles-yoshi       		7		1		0.14
# handsometom-kirby   		16		7		0.44
# hansolo-fox         		2		0		0.00
# heropie-falcon      		2		1		0.50
# heropie-fox         		5		3		0.60
# heropie-pika        		1		0		0.00
# hotspank-falcon     		1		0		0.00
# hotspank-puff       		1		0		0.00
# jaimehr-falcon      		7		3		0.43
# jaimehr-kirby       		3		2		0.67
# jaimehr-pika        		4		2		0.50
# jaimehr-samus       		3		2		0.67
# jam-pika            		10		5		0.50
# jamjar-kirby        		4		0		0.00
# janco-kirby         		3		1		0.33
# janco-pika          		8		1		0.12
# janitor-falcon      		2		1		0.50
# janitor-pika        		2		0		0.00
# janitor-yoshi       		3		0		0.00
# jason-falcon        		2		0		0.00
# jason-kirby         		1		0		0.00
# jimmyjoe-kirby      		1		0		0.00
# jimmyjoe-pika       		3		0		0.00
# karajan-dk          		1		0		0.00
# karajan-falcon      		1		0		0.00
# karajan-fox         		7		3		0.43
# karajan-kirby       		1		0		0.00
# karajan-pika        		1		0		0.00
# kelvinheit-falcon   		1		1		1.00
# kelvinheit-mario    		2		0		0.00
# kerokeroppi-falcon  		6		1		0.17
# kerokeroppi-kirby   		10		6		0.60
# kerokeroppi-pika    		82		45		0.55
# kimimaru-mario      		10		3		0.30
# kort-falcon         		1		1		1.00
# kort-link           		6		0		0.00
# kort-pika           		1		1		1.00
# kurabba-yoshi       		10		4		0.40
# kyletree-pika       		2		0		0.00
# kysk-falcon         		2		1		0.50
# kysk-kirby          		15		10		0.67
# ld-fox              		20		10		0.50
# letsgo-fox          		3		1		0.33
# letsgo-pika         		1		0		0.00
# lordnarwhal-falcon  		8		3		0.38
# lordnarwhal-kirby   		2		1		0.50
# lordnarwhal-mario   		2		0		0.00
# lorenzo-dk          		11		5		0.45
# lowww-falcon        		1		1		1.00
# lowww-fox           		1		1		1.00
# lowww-pika          		2		0		0.00
# madrush-falcon      		11		3		0.27
# madrush-kirby       		1		1		1.00
# maliki-falcon       		2		0		0.00
# maliki-pika         		3		1		0.33
# marbles-ness        		1		1		1.00
# marbles-pika        		16		5		0.31
# mariguas-falcon     		2		0		0.00
# mariguas-kirby      		2		1		0.50
# mariguas-pika       		75		45		0.60
# mojomonkey-falcon   		10		6		0.60
# mojomonkey-kirby    		1		0		0.00
# mrsir-samus         		9		2		0.22
# near-falcon         		1		1		1.00
# near-fox            		1		1		1.00
# near-luigi          		1		1		1.00
# near-mario          		1		1		1.00
# near-puff           		1		0		0.00
# nintendude-fox      		21		8		0.38
# nintendude-mario    		3		1		0.33
# nothing-falcon      		5		1		0.20
# nta-falcon          		4		2		0.50
# nta-mario           		4		3		0.75
# nta-pika            		3		2		0.67
# nta-samus           		2		0		0.00
# onski-kirby         		6		0		0.00
# polarbair-mario     		3		1		0.33
# poohbearninja-falcon		2		0		0.00
# preston-kirby       		11		6		0.55
# preston-mario       		1		1		1.00
# prince-yoshi        		15		7		0.47
# reckless-falcon     		3		2		0.67
# revan-kirby         		71		45		0.63
# rizner-kirby        		6		2		0.33
# robert-kirby        		1		0		0.00
# robert-pika         		2		1		0.50
# sax-falcon          		3		0		0.00
# sax-mario           		1		0		0.00
# scoback-ness        		2		0		0.00
# scoback-puff        		3		0		0.00
# sedda-dk            		1		0		0.00
# sedda-fox           		8		4		0.50
# sextc-falcon        		5		2		0.40
# sextc-fox           		1		0		0.00
# shears-luigi        		4		1		0.25
# shears-pika         		30		12		0.40
# shears-yoshi        		22		11		0.50
# shihman-falcon      		8		2		0.25
# smashjesus-falcon   		2		0		0.00
# sotoh-falcon        		1		0		0.00
# sotoh-kirby         		3		2		0.67
# sotoh-pika          		3		0		0.00
# starking-fox        		1		1		1.00
# starking-kirby      		13		7		0.54
# starking-samus      		1		1		1.00
# stranded-dk         		1		1		1.00
# stranded-falcon     		10		10		1.00
# stranded-kirby      		1		1		1.00
# stranded-pika       		20		11		0.55
# superboomfan-dk     		3		2		0.67
# superboomfan-falcon 		31		20		0.65
# superboomfan-fox    		3		3		1.00
# superboomfan-kirby  		39		35		0.90
# superboomfan-link   		1		1		1.00
# superboomfan-pika   		66		58		0.88
# superboomfan-puff   		3		3		1.00
# superboomfan-yoshi  		1		0		0.00
# tacos-dk            		6		2		0.33
# tacos-falcon        		13		4		0.31
# tacos-fox           		1		0		0.00
# tacos-kirby         		5		4		0.80
# tacos-link          		1		0		0.00
# tacos-pika          		17		7		0.41
# tacos-puff          		1		0		0.00
# tacos-yoshi         		36		25		0.69
# taimai-falcon       		4		2		0.50
# taimai-fox          		6		2		0.33
# tank-falcon         		1		0		0.00
# tank-fox            		1		0		0.00
# thebigd-kirby       		4		3		0.75
# thebigd-pika        		6		1		0.17
# thekuzinator-kirby  		1		0		0.00
# thekuzinator-yoshi  		3		0		0.00
# theprotagonist-fox  		3		1		0.33
# thez-falcon         		1		0		0.00
# thez-fox            		12		5		0.42
# thez-kirby          		7		2		0.29
# thez-pika           		35		18		0.51
# thez-yoshi          		2		0		0.00
# tyhiggz-yoshi       		6		2		0.33
# vanillarin-kirby    		4		0		0.00
# vinsanity-fox       		8		4		0.50
# wangera-puff        		22		14		0.64
# wario-pika          		15		11		0.73
# wizzrobe-pika       		1		0		0.00
# wizzrobe-yoshi      		53		21		0.40
# ybombb-falcon       		11		6		0.55
# ybombb-puff         		9		4		0.44
# ybombb-yoshi        		4		2		0.50
# yukun-falcon        		4		0		0.00
# yukun-pika          		2		1		0.50
# yunque-puff         		3		0		0.00
# zantetsu-falcon     		4		0		0.00
# zantetsu-pika       		1		0		0.00
# zeppelin-falcon     		6		4		0.67
# zeppelin-pika       		1		0		0.00
# zero-falcon         		12		5		0.42
# zero-pika           		1		0		0.00
#
#
# INDIVIDUAL STATS
#
# player-character		# games		# wins		% win
# polarbair-mario          		3		1		0.33
#
# TOTALS                   		3		1		0.33
#
# player-character		# games		# wins		% win
# reckless-falcon          		3		2		0.67
#
# TOTALS                   		3		2		0.67

# %%
prinf.print_plchar_ranks(level_limits, skip_these_players, individual_stats, which_rankings='player')
# Out:
# Rank 	 Name                           Rating
# 1 	 superboomfan                   0.181357766204
# 2 	 alvin                          0.09942074266
# 3 	 wario                          0.0728545372347
# 4 	 mariguas                       0.0671983421879
# 5 	 wangera                        0.0566978546017
# 6 	 kerokeroppi                    0.0519561114524
# 7 	 wizzrobe                       0.0476282605385
# 8 	 tacos                          0.042774198204
# 9 	 thez                           0.0401008548713
# 10 	 kysk                           0.0321597315556
# 11 	 kurabba                        0.0309530904063
# 12 	 fireblaster                    0.0258096189292
# 13 	 prince                         0.0233670102393
# 14 	 dext3r                         0.0217632333656
# 15 	 revan                          0.0194443160069
# 16 	 firo                           0.0131060779008
# 17 	 near                           0.0113187295702
# 18 	 d35                            0.0113026296531
# 19 	 stranded                       0.00984700448662
# 20 	 barksanchez                    0.00878323842959
# 21 	 handsometom                    0.00708129760104
# 22 	 kort                           0.00675900816543
# 23 	 derek                          0.00546393277813
# 24 	 zero                           0.00492760611502
# 25 	 jaimehr                        0.00354347894492
# 26 	 janitor                        0.00342804777204
# 27 	 starking                       0.00338228652839
# 28 	 ld                             0.00336553609706
# 29 	 taimai                         0.0031871062015
# 30 	 cobr                           0.00312985651552
# 31 	 dtan                           0.00303788766424
# 32 	 shears                         0.00301076971761
# 33 	 yukun                          0.00264345125675
# 34 	 dfx                            0.00123454568862
# 35 	 clubbadubba                    0.00119000394081
# 36 	 comboblaze                     0.00115472985654
# 37 	 connor                         0.00108359253992
# 38 	 nothing                        0.000987529730139
# 39 	 robert                         0.000987529730139
# 40 	 lorenzo                        0.00095004050415
# 41 	 ybombb                         0.000864495839788
# 42 	 bonobono                       0.000639124051293
# 43 	 heropie                        0.000522172177186
# 44 	 marbles                        0.000513356303456
# 45 	 nta                            0.000459446375885
# 46 	 nintendude                     0.000451487033341
# 47 	 mojomonkey                     0.000429705017599
# 48 	 kimimaru                       0.0004012365644
# 49 	 vinsanity                      0.000383166782031
# 50 	 shihman                        0.000380115223225
