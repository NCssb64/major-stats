# %%
import print_info

# %%
# FIRST CHOOSE FILTERS

# Currently there are three filter possibilities:
#   1. selecting level of play (pools/bracket/top8)
#   2. omitting a set of players from the query
#   3. selecting specific players for individual stats

# [1] LEVEL OF PLAY
# These numbers determine what games (e.g. pools, top32, winners finals) to include.
# To include all games, leave as [0,9]
level_limits = [0,9]
# Change the numbers to match your desired filter as follows:
# [0,9] includes all games from pools to grand finals ("gf2")
# [0,0] includes just pools games
# [5,5] includes just top8 games (but not wf, lf, or gf)
# [2,3] includes all top64 and top32 games (but not top16 or top8 games)
# 'pools'    = 0
# 'bracket'  = 1
# 'top64'    = 2
# 'top32'    = 3
# 'top16'    = 4
# 'top8'     = 5
# 'lf'       = 6
# 'wf'       = 7
# 'gf'       = 8
# 'gf2'      = 9

# [2] SKIP PLAYERS
# Any name included will be skipped during the query
skip_these_players = {
    'isai':1,
    'alvin':1,
    'superboomfan':1
    }


# [3] INDIVIDUAL STATS
# print stats for each player in this list:
individual_stats = [
    'ld',
    'dext3r'
    ]



# PRINT QUERY RESULTS
print_info.print_smash_stats( level_limits, skip_these_players, individual_stats )
# Out:
# SMASH ARCHIVE QUERY RESULTS
#
# from recorded games at the following events:
# 		genesis 3		2016
# 		pound		2016
# 		snosa2		2016
# 		beast7		2017
# 		goml		2016
# 		ssc		2016
#
# Skipping these players:
# 		alvin
# 		superboomfan
# 		isai
# Includes pools games through gf2
# Number of players in query: 150
# Number of games in query: 578
#
#
# MATCHUP PERCENTAGES
#
# char1	char2 	# games 	char1 wins 	prct win by char 1
# pika	pika	110.0		55.0		0.50
# falcon	pika	64.0		24.0		0.38
# pika	yoshi	58.0		34.0		0.59
# pika	kirby	55.0		37.0		0.67
# falcon	falcon	40.0		20.0		0.50
# puff	pika	31.0		18.0		0.58
# fox	pika	30.0		9.0		0.30
# falcon	yoshi	28.0		10.0		0.36
# fox	fox	28.0		14.0		0.50
# yoshi	kirby	23.0		12.0		0.52
# fox	falcon	21.0		12.0		0.57
# falcon	kirby	19.0		10.0		0.53
# link	falcon	14.0		4.0		0.29
# pika	mario	12.0		6.0		0.50
# falcon	ness	11.0		7.0		0.64
# puff	falcon	10.0		4.0		0.40
# puff	yoshi	10.0		4.0		0.40
# puff	kirby	10.0		4.0		0.40
# fox	kirby	9.0		6.0		0.67
# yoshi	yoshi	8.0		4.0		0.50
# fox	yoshi	7.0		2.0		0.29
# pika	dk	7.0		5.0		0.71
# kirby	kirby	6.0		3.0		0.50
# yoshi	ness	5.0		4.0		0.80
# link	pika	5.0		1.0		0.20
# link	kirby	4.0		1.0		0.25
# falcon	mario	4.0		4.0		1.00
# mario	luigi	4.0		3.0		0.75
# puff	mario	3.0		3.0		1.00
# kirby	luigi	3.0		1.0		0.33
# fox	puff	3.0		2.0		0.67
# link	yoshi	3.0		0.0		0.00
# dk	kirby	3.0		3.0		1.00
# pika	ness	3.0		2.0		0.67
# mario	kirby	3.0		1.0		0.33
# mario	ness	2.0		1.0		0.50
# fox	dk	2.0		0.0		0.00
# samus	falcon	2.0		0.0		0.00
# link	dk	2.0		1.0		0.50
# puff	puff	2.0		1.0		0.50
# mario	dk	2.0		0.0		0.00
# samus	fox	2.0		0.0		0.00
# samus	kirby	2.0		1.0		0.50
# samus	link	2.0		2.0		1.00
# dk	ness	1.0		1.0		1.00
# link	fox	1.0		1.0		1.00
# fox	ness	1.0		1.0		1.00
#
# CHARACTER-BASED GAMES
# (excludes dittos)
# char		# games		% wins
# pika		265.0		0.61
# falcon		173.0		0.47
# yoshi		134.0		0.54
# kirby		131.0		0.41
# fox		76.0		0.45
# puff		67.0		0.51
# link		31.0		0.26
# mario		30.0		0.37
# ness		23.0		0.30
# dk		17.0		0.65
# samus		8.0		0.38
# luigi		7.0		0.43
#
# Total games 578.0 (two characters appear per game)
# char		# appearances	% of total
# pika		375.0		0.32
# falcon		213.0		0.18
# yoshi		142.0		0.12
# kirby		137.0		0.12
# fox		104.0		0.09
# puff		69.0		0.06
# link		31.0		0.03
# mario		30.0		0.03
# ness		23.0		0.02
# dk		17.0		0.01
# samus		8.0		0.01
# luigi		7.0		0.01
#
# Player-character game data
#
# player-character		# games		# wins		% win
# kerokeroppi-pika    		53		32		0.60
# revan-kirby         		50		32		0.64
# barksanchez-pika    		44		27		0.61
# mariguas-pika       		33		27		0.82
# thez-pika           		29		18		0.62
# wizzrobe-yoshi      		27		15		0.56
# wangera-puff        		26		21		0.81
# tacos-yoshi         		25		18		0.72
# ld-fox              		24		16		0.67
# shears-pika         		24		11		0.46
# fireblaster-yoshi   		22		11		0.50
# dext3r-pika         		22		8		0.36
# derek-pika          		17		10		0.59
# nothing-falcon      		16		7		0.44
# lordnarwhal-falcon  		16		7		0.44
# zero-falcon         		16		8		0.50
# prince-yoshi        		12		6		0.50
# jam-pika            		12		7		0.58
# jaimehr-falcon      		12		9		0.75
# kimimaru-mario      		12		5		0.42
# kort-link           		12		2		0.17
# firo-ness           		12		7		0.58
# comboblaze-falcon   		12		7		0.58
# clubbadubba-pika    		11		6		0.55
# stranded-falcon     		11		9		0.82
# professorwizard-kirby		10		5		0.50
# ctg-puff            		10		5		0.50
# kurabba-yoshi       		10		4		0.40
# lorenzo-dk          		10		8		0.80
# tacos-pika          		9		7		0.78
# tacos-falcon        		9		6		0.67
# stranded-pika       		9		4		0.44
# daniel-falcon       		9		2		0.22
# firo-link           		9		3		0.33
# kerokeroppi-falcon  		8		3		0.38
# banze-pika          		8		4		0.50
# nintendude-fox      		8		2		0.25
# kerokeroppi-kirby   		8		5		0.62
# ybombb-puff         		7		3		0.43
# wario-pika          		7		7		1.00
# shears-yoshi        		7		5		0.71
# dfx-falcon          		6		2		0.33
# theprotagonist-fox  		6		4		0.67
# captainfabulous-falcon		6		4		0.67
# heropie-pika        		6		2		0.33
# hungrybox-kirby     		6		2		0.33
# ern-puff            		6		2		0.33
# gravyfingers-pika   		6		4		0.67
# mrsir-samus         		6		2		0.33
# fckvwls-falcon      		6		2		0.33
# d35-pika            		5		1		0.20
# shears-luigi        		5		2		0.40
# korobeniki-yoshi    		5		1		0.20
# miniohh-kirby       		5		2		0.40
# jayr-falcon         		5		1		0.20
# bonobono-yoshi      		5		1		0.20
# umbra-falcon        		5		0		0.00
# xor-fox             		5		4		0.80
# thebigd-kirby       		5		1		0.20
# fruity-mario        		5		0		0.00
# pewpewu-fox         		5		1		0.20
# iceking-pika        		5		1		0.20
# stevieg-fox         		4		2		0.50
# pete-yoshi          		4		4		1.00
# robert-pika         		4		2		0.50
# darkhorse-puff      		4		1		0.25
# daniels-pika        		4		4		1.00
# barksanchez-mario   		4		3		0.75
# captainl-fox        		4		2		0.50
# sextc-falcon        		4		2		0.50
# janitor-falcon      		4		1		0.25
# marlwolf-falcon     		4		2		0.50
# zhu-fox             		4		0		0.00
# freean-falcon       		4		1		0.25
# grahamaglam-link    		4		2		0.50
# studstill-kirby     		4		0		0.00
# khakis-puff         		4		0		0.00
# preston-kirby       		4		2		0.50
# daniel-pika         		3		3		1.00
# aubfox-fox          		3		1		0.33
# madrush-falcon      		3		1		0.33
# mariguas-falcon     		3		2		0.67
# shalaka-pika        		3		2		0.67
# shake-link          		3		1		0.33
# kort-pika           		3		3		1.00
# bon-kirby           		3		1		0.33
# thekuzinator-yoshi  		3		2		0.67
# koro-yoshi          		3		1		0.33
# masterhandjob-pika  		3		2		0.67
# jimmyjoe-pika       		3		2		0.67
# kerokeroppi-fox     		3		2		0.67
# klumsy-falcon       		3		1		0.33
# tank-fox            		3		2		0.67
# hotspank-pika       		3		1		0.33
# sotoh-falcon        		3		2		0.67
# rith-pika           		3		3		1.00
# knitephox-falcon    		3		1		0.33
# daniels-fox         		3		0		0.00
# tyhiggz-yoshi       		3		2		0.67
# yobolight-yoshi     		3		2		0.67
# q-falcon            		3		2		0.67
# sotoh-kirby         		3		2		0.67
# blisstex-pika       		3		1		0.33
# heropie-fox         		3		0		0.00
# lordnarwhal-kirby   		3		1		0.33
# clubbadubba-falcon  		3		2		0.67
# ivor-fox            		3		2		0.67
# fireblaster-mario   		3		2		0.67
# yunque-puff         		3		1		0.33
# darkhorse-falcon    		3		3		1.00
# lldl-fox            		3		1		0.33
# firo-falcon         		2		1		0.50
# ybombb-falcon       		2		1		0.50
# dfx-fox             		2		1		0.50
# kristoff-ness       		2		0		0.00
# greeno-puff         		2		0		0.00
# elel-fox            		2		0		0.00
# senorhen10r-pika    		2		0		0.00
# jamjar-kirby        		2		0		0.00
# gumbolaya-ness      		2		0		0.00
# squanch-pika        		2		0		0.00
# snorlax-dk          		2		0		0.00
# imdabes-pika        		2		0		0.00
# ybombb-yoshi        		2		2		1.00
# nattybro-kirby      		2		1		0.50
# marbles-pika        		2		2		1.00
# justin-falcon       		2		0		0.00
# jpeghero-kirby      		2		0		0.00
# tank-yoshi          		2		2		1.00
# thez-yoshi          		2		0		0.00
# weedwhack-yoshi     		2		0		0.00
# karajan-fox         		2		1		0.50
# gamer4life-kirby    		2		0		0.00
# cwicbeam-yoshi      		2		0		0.00
# shake-fox           		2		0		0.00
# thez-fox            		2		2		1.00
# barksanchez-falcon  		2		1		0.50
# mrryanness-ness     		2		0		0.00
# zuko-pika           		2		0		0.00
# krypto-pika         		2		0		0.00
# nacl-kirby          		2		2		1.00
# grahamaglam-mario   		2		0		0.00
# bowl-pika           		2		2		1.00
# h20-fox             		2		0		0.00
# holosly-falcon      		2		0		0.00
# justin-pika         		2		2		1.00
# maliki-falcon       		2		2		1.00
# autobaun-kirby      		2		0		0.00
# shihman-falcon      		2		0		0.00
# umbra-fox           		2		1		0.50
# onski-kirby         		2		0		0.00
# maliki-pika         		2		0		0.00
# jimmyjoe-puff       		2		0		0.00
# eggmode-pika        		2		0		0.00
# nesskhalifa-falcon  		2		2		1.00
# mokkori-kirby       		2		0		0.00
# sotoh-fox           		2		2		1.00
# poohbearninja-falcon		2		0		0.00
# wookiee-pika        		2		2		1.00
# sheermadness-yoshi  		2		0		0.00
# yobolight-ness      		2		0		0.00
# cobr-falcon         		2		2		1.00
# sonicfuzz-pika      		2		0		0.00
# kyletree-pika       		2		0		0.00
# bard-kirby          		2		0		0.00
# dragonlota-kirby    		2		0		0.00
# wookiee-kirby       		2		0		0.00
# thez-kirby          		2		1		0.50
# janco-pika          		2		2		1.00
# wincancel-link      		2		0		0.00
# dogsjohnson-falcon  		2		0		0.00
# nesskhalifa-ness    		2		0		0.00
# blink-pika          		2		2		1.00
# masquerade-mario    		2		0		0.00
# white-pika          		2		2		1.00
# capsui-fox          		2		0		0.00
# starchild-puff      		2		2		1.00
# heropie-falcon      		2		1		0.50
# salt-pika           		2		2		1.00
# razz-falcon         		2		0		0.00
# amida-kirby         		2		0		0.00
# stranded-fox        		1		1		1.00
# alacarte-falcon     		1		1		1.00
# fckvwls-puff        		1		0		0.00
# drewgong-fox        		1		0		0.00
# g0d-pika            		1		0		0.00
# barksanchez-kirby   		1		0		0.00
# daniel-samus        		1		1		1.00
# tot-pika            		1		0		0.00
# tacos-dk            		1		0		0.00
# thekuzinator-pika   		1		0		0.00
# near-puff           		1		0		0.00
# thez-falcon         		1		0		0.00
# janitor-yoshi       		1		0		0.00
# q-samus             		1		0		0.00
# g0d-falcon          		1		0		0.00
# drewgong-falcon     		1		0		0.00
# banze-kirby         		1		0		0.00
# captainfabulous-dk  		1		1		1.00
# tonester-pika       		1		0		0.00
# precookedbread-ness 		1		0		0.00
# alacarte-pika       		1		1		1.00
# keagsbsmashin-kirby 		1		0		0.00
# near-fox            		1		1		1.00
# near-luigi          		1		1		1.00
# fckvwls-dk          		1		0		0.00
# freddy-falcon       		1		0		0.00
# tot-fox             		1		0		0.00
# near-falcon         		1		1		1.00
# kort-falcon         		1		1		1.00
# karajan-dk          		1		1		1.00
# freddy-link         		1		0		0.00
# iceking-falcon      		1		1		1.00
# precookedbread-puff 		1		0		0.00
# tank-falcon         		1		0		0.00
# alacarte-fox        		1		0		0.00
# xor-kirby           		1		0		0.00
# thekuzinator-kirby  		1		0		0.00
# freean-luigi        		1		0		0.00
# keagsbsmashin-pika  		1		0		0.00
# nintendude-mario    		1		0		0.00
# sotoh-pika          		1		0		0.00
# tonester-kirby      		1		0		0.00
# near-mario          		1		1		1.00
# karajan-kirby       		1		0		0.00
# comboblaze-dk       		1		1		1.00
# mariguas-kirby      		1		0		0.00
# jimmyjoe-kirby      		1		0		0.00
# rith-falcon         		1		1		1.00
# blink-kirby         		1		0		0.00
# dfx-pika            		1		1		1.00
# nattybro-pika       		1		0		0.00
#
#
# INDIVIDUAL STATS
#
# player-character		# games		# wins		% win
# ld-fox              		24		16		0.67
#
# TOTALS              		24		16		0.67
#
# player-character		# games		# wins		% win
# dext3r-pika         		22		8		0.36
#
# TOTALS              		22		8		0.36
