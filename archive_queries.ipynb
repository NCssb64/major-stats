# %%
import print_info as prinf
import numpy as np

# FIRST CHOOSE FILTERS

# Filter possibilities:
#   1. selecting level of play (pools/bracket/top8)
#   2. omitting a set of players from the query
#   3. selecting specific players for individual stats
#   4. formatting output for markdown

# [1] LEVEL OF PLAY
# These numbers determine what games (e.g. pools, top32, winners finals) to include.
# To include all games, leave as [0,9]
level_limits = [0,9]
# Change the numbers to match your desired filter as follows:
# [0,9] includes all games from pools to grand finals ("gf2")
# [0,0] includes just pools games
# [5,5] includes just top8 games (but not wf, lf, or gf)
# [2,3] includes all top64 and top32 games (but not top16 or top8 games)
# 'pools'    = 0
# 'bracket'  = 1
# 'top64'    = 2
# 'top32'    = 3
# 'top16'    = 4
# 'top8'     = 5
# 'lf'       = 6
# 'wf'       = 7
# 'gf'       = 8
# 'gf2'      = 9

# [2] SKIP PLAYERS
# Any name included will be skipped during the query
skip_these_players = {
    #'isai':1
    #'alvin':1,
    #'superboomfan':1
    }


# [3] INDIVIDUAL STATS
# print stats for each player in this list:
individual_stats = [
    #'d35',
    #'near',
    #'dtan',
    #'wizzrobe',
    #'zero',
    #'barksanchez',
    #'firo',
    #'fireblaster'
    #'hungrybox'
    #'isai',
    #'superboomfan',
    #'tacos',
    #'alvin',
    #'revan',
    #'ld',
    #'dext3r'
    ]

# [4] Markdown_table or html readable?
markdown_flag = False


# PRINT QUERY RESULTS
prinf.print_smash_stats( level_limits, skip_these_players, individual_stats, markdown_flag )
# Out:
# SMASH ARCHIVE QUERY RESULTS
#
# from recorded games at the following events:
# 		2016 genesis 3
# 		2016 pound
# 		2016 goml
# 		2016 snosa2
# 		2017 beast7
# 		2016 ssc
# 		2017 genesis 4
# 		2016 shine
# 		2016 apex
# 		2016 summit
# 		2016 superboomed
# 		2016 bossbattle2
# 		2016 dpotg
# 		2017 kansai
# Includes pools games through gf2
# Number of players in query: 290
# Number of games in query: 1510
#
#
# MATCHUP PERCENTAGES
#
# char1 	char2 	# games 	char1 wins 	prct win by char 1
# pika	pika	288.0		144.0		0.50
# pika	kirby	174.0		97.0		0.56
# pika	falcon	158.0		82.0		0.52
# pika	yoshi	137.0		72.0		0.53
# falcon	falcon	88.0		44.0		0.50
# pika	fox	72.0		49.0		0.68
# yoshi	kirby	68.0		26.0		0.38
# falcon	fox	66.0		28.0		0.42
# falcon	yoshi	64.0		27.0		0.42
# pika	puff	58.0		31.0		0.53
# falcon	kirby	46.0		20.0		0.43
# fox	fox	34.0		17.0		0.50
# falcon	puff	30.0		19.0		0.63
# fox	kirby	29.0		18.0		0.62
# yoshi	fox	29.0		14.0		0.48
# kirby	puff	27.0		13.0		0.48
# ...

# %%
prinf.print_plchar_ranks(level_limits, skip_these_players, individual_stats, which_rankings='player')
# Out:
# Rank 	 Name                           Rating
# 1 	 superboomfan                   0.0584572240441
# 2 	 alvin                          0.033570315882
# 3 	 kysk                           0.0284886489666
# 4 	 wario                          0.0202564103581
# 5 	 mariguas                       0.0180786934537
# 6 	 wangera                        0.0165782686576
# 7 	 isai                           0.0165582423457
# 8 	 kerokeroppi                    0.0157392942784
# 9 	 gyaki                          0.0138588165115
# 10 	 wizzrobe                       0.0134221470696
# 11 	 tacos                          0.0126608484151
# 12 	 kurabba                        0.0108754183879
# 13 	 masaru                         0.00982410160243
# 14 	 micchan                        0.00855973990382
# 15 	 taimai                         0.00833216291689
# 16 	 thez                           0.0081724070605
# 17 	 fireblaster                    0.0077210091345
# ...
