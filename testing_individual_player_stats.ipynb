# %%
import smasharchive

db = smasharchive.smashdb()
db.tournament_name_skip['kansai'] = 0
db.level_limits = [0,9]
db.refilter_archive()
db.refilter_archive_for_ssbcentral(threshold=10)
# this filters out any game that is not between two players with ssbcentral ratings,
# and filters out games between players whose ssbcentral rating differs by more than threshold
# Out:
# initiatlizing smashdb

# %%
print("")
db.print_mu_stats(10)
db.print_header()
db.print_playerchar()
# Out:
# MATCHUP PERCENTAGES
#
# | char1       | char2       | # games |  % win char1|
# |:------------|:------------|--------:|------------:|
# | pika        | yoshi       | 125.0   |         0.55|
# | pika        | kirby       | 116.0   |         0.54|
# | pika        | falcon      | 101.0   |         0.52|
# | yoshi       | falcon      | 57.0    |         0.53|
# | kirby       | yoshi       | 40.0    |         0.78|
# | puff        | pika        | 37.0    |         0.51|
# | pika        | fox         | 33.0    |         0.70|
# | kirby       | falcon      | 24.0    |         0.71|
# | falcon      | fox         | 20.0    |         0.50|
# | kirby       | puff        | 17.0    |         0.71|
# | link        | kirby       | 17.0    |         0.53|
# | fox         | yoshi       | 14.0    |         0.57|
# | falcon      | puff        | 12.0    |         0.50|
# | mario       | yoshi       | 11.0    |         0.64|
# | fox         | kirby       | 11.0    |         0.64|
# ...

# %%
import smasharchive

db = smasharchive.smashdb()
db.level_limits = [3,9]
db.refilter_archive()
db.refilter_archive_for_ssbcentral(threshold=10)


print("")
# db.print_mu_stats(10)
"""
print_plchar_ranks(self, num_to_print=50, which_rankings='pchar', centered_player=None, degree_scale=False,
                          transpose_flag=True, remove_winless=False)
"""
db.print_plchar_ranks(0, which_rankings=None, remove_winless=False)
# Out:
# initiatlizing smashdb
#
# Rank    Name                 Rating     # Games   best win                     worst loss
# -----------------------------------------------------------------------------------------------------
# 1    superboomfan           0.1597960       150   alvin                   2,   revan                  12
# 2    alvin                  0.0816163        71   superboomfan            1,   sheermadness           22
# 3    mariguas               0.0770173       132   superboomfan            1,   prince                 16
# 4    wario                  0.0628374        15   superboomfan            1,   superboomfan            1
# 5    isai                   0.0622052        99   superboomfan            1,   jaimehr                20
# 6    tacos                  0.0556181        99   superboomfan            1,   janitor                26
# 7    wangera                0.0530466        31   superboomfan            1,   dext3r                 11
# ...

# %%
import smasharchive

db = smasharchive.smashdb()
db.level_limits = [1,9]
db.refilter_archive()
db.refilter_archive_for_ssbcentral(threshold=10)

print("")

# def scout_report(self, pname, char_toggle=False):
char_flag = False
db.scout_report('mariguas', char_flag)
db.scout_report('alvin', char_flag)
db.scout_report('superboomfan', char_flag)
db.scout_report('wario', char_flag)
db.scout_report('isai', char_flag)
db.scout_report('wizzrobe', char_flag)
db.scout_report('dext3r', char_flag)
db.scout_report('tacos', char_flag)
db.scout_report('thez', char_flag)
# Out:
# initiatlizing smashdb
#
# mariguas                  W   L
#    tacos                  2   3
#    superboomfan           2  12
#    isai                  10  14
#    wario                  0   3
#    wizzrobe               6   1
#    kerokeroppi            7   0
#    thez                  12   4
#    revan                  3   0
#    dext3r                12   1
#    firo                   3   0
#    janitor                2   0
#    sotoh                  2   0
#    alvin                  5  13
#    prince                 3   2
#    zero                   7   3
#    handsometom            2   0
#
# alvin                     W   L
#    fireblaster            1   2
#    tacos                  5   3
#    superboomfan           9   5
#    mariguas              13   5
#    kerokeroppi            3   0
#    revan                  2   0
#    lordnarwhal            2   0
#    barksanchez            8   4
#    kimimaru               2   0
#    sotoh                  2   0
# ...

# %%
# def scout_report(self, pname, char_toggle=False):
char_flag = True
db.scout_report('mariguas', char_flag)
db.scout_report('alvin', char_flag)
db.scout_report('superboomfan', char_flag)
db.scout_report('wario', char_flag)
db.scout_report('isai', char_flag)
db.scout_report('wizzrobe', char_flag)
db.scout_report('dext3r', char_flag)
db.scout_report('tacos', char_flag)
db.scout_report('thez', char_flag)
# Out:
# mariguas-pika             W   L
#    tacos-yoshi            2   2
#    superboomfan-falcon    1   2
#    wario-pika             0   2
#    wizzrobe-yoshi         6   1
#    isai-fox               3   4
#    isai-pika              6   7
#    superboomfan-pika      1   9
#    kerokeroppi-pika       5   0
#    thez-pika              2   1
#    kerokeroppi-falcon     2   0
#    revan-kirby            3   0
#    dext3r-pika            9   1
#    firo-ness              3   0
#    thez-fox               2   2
#    thez-yoshi             3   0
#    thez-falcon            2   0
#    sotoh-kirby            1   0
#    sotoh-falcon           1   0
#    isai-samus             1   0
#    isai-yoshi             0   3
#    alvin-falcon           2   7
#    prince-yoshi           3   2
#    alvin-pika             2   5
#    thez-kirby             3   1
#    zero-falcon            1   2
#    janitor-pika           2   0
#    handsometom-kirby      2   0
#    dext3r-falcon          2   0
# ...
