# %%
import smasharchive, smashplots

db = smasharchive.smashdb()
db.tournament_name_skip['kansai'] = 0
db.level_limits = [5,9]
db.refilter_archive()
db.refilter_archive_for_ssbcentral(threshold=10)
# Out:
# initiatlizing smashdb

# %%
print("")
db.print_mu_stats(10)
db.print_header()
db.print_playerchar()
# Out:
# MATCHUP PERCENTAGES
#
# | char1       | char2       | # games |  % win char1|
# |:------------|:------------|--------:|------------:|
# | pika        | yoshi       | 75.0    |         0.56|
# | pika        | kirby       | 60.0    |         0.50|
# | pika        | falcon      | 44.0    |         0.52|
# | kirby       | yoshi       | 28.0    |         0.75|
# | link        | kirby       | 16.0    |         0.56|
# | pika        | puff        | 15.0    |         0.60|
# | pika        | fox         | 13.0    |         0.62|
#
# SMASH ARCHIVE QUERY RESULTS
#
# | Name             | Players | data-points |  Region |  Version |
# |:-----------------|--------:|------------:|--------:|---------:|
# | 2016 genesis 3   |     238 |          36 |      NA |        U |
# | 2016 pound       |     107 |          32 |      NA |        U |
# | 2016 goml        |      83 |          34 |      NA |        U |
# | 2016 snosa2      |      96 |          36 |      NA |        U |
# | 2017 beast7      |      43 |          30 |  Europe |        U |
# | 2016 ssc         |     314 |          38 |      NA |        U |
# | 2017 genesis 4   |     185 |          21 |      NA |        U |
# | 2016 shine       |     109 |          30 |      NA |        U |
# | 2016 apex        |      54 |          22 |      NA |        U |
# | 2016 summit      |      28 |          13 |      NA |        U |
# | 2016 superboomed |      80 |          34 |      NA |        U |
# | 2016 bossbattle2 |      90 |          34 |      NA |        U |
# | 2016 dpotg       |      73 |          16 |      NA |        U |
# | 2017 ceodreamland|      53 |          25 |      NA |        U |
#
# * Includes top8 games through gf2
# * Number of players in query: 33
# * Number of games in query: 401
#
#
# Player-character game data
#
# player-character		# games		# wins		% win
# alvin-falcon        		20		15		0.75
# alvin-fox           		1		0		0.00
# alvin-mario         		2		2		1.00
# alvin-pika          		19		12		0.63
# alvin-samus         		1		0		0.00
# alvin-yoshi         		2		1		0.50
# barksanchez-falcon  		1		1		1.00
# barksanchez-mario   		4		3		0.75
# barksanchez-pika    		77		31		0.40
# cobr-falcon         		2		2		1.00
# cobr-kirby          		3		1		0.33
# ctg-puff            		3		0		0.00
# derek-pika          		9		5		0.56
# dext3r-pika         		14		6		0.43
# dtan-kirby          		13		7		0.54
# fireblaster-mario   		2		1		0.50
# fireblaster-pika    		1		0		0.00
# fireblaster-yoshi   		39		14		0.36
# firo-link           		4		1		0.25
# firo-ness           		3		0		0.00
# handsometom-kirby   		4		1		0.25
# isai-dk             		3		1		0.33
# isai-fox            		13		8		0.62
# isai-link           		15		9		0.60
# isai-luigi          		2		1		0.50
# isai-mario          		2		0		0.00
# isai-ness           		1		0		0.00
# isai-pika           		15		13		0.87
# isai-puff           		2		1		0.50
# isai-samus          		1		0		0.00
# isai-yoshi          		6		3		0.50
# jaimehr-falcon      		4		1		0.25
# kerokeroppi-falcon  		1		0		0.00
# kerokeroppi-kirby   		4		1		0.25
# kerokeroppi-pika    		52		22		0.42
# kurabba-yoshi       		3		0		0.00
# ld-fox              		4		1		0.25
# lorenzo-dk          		4		1		0.25
# marbles-ness        		1		1		1.00
# marbles-pika        		6		2		0.33
# mariguas-falcon     		2		0		0.00
# mariguas-kirby      		2		1		0.50
# mariguas-pika       		57		28		0.49
# nintendude-fox      		3		0		0.00
# nta-falcon          		1		0		0.00
# nta-samus           		2		0		0.00
# revan-kirby         		49		25		0.51
# shears-luigi        		5		1		0.20
# shears-pika         		2		0		0.00
# shears-yoshi        		10		4		0.40
# sheermadness-pika   		5		3		0.60
# sheermadness-yoshi  		4		0		0.00
# starking-kirby      		13		7		0.54
# stranded-falcon     		1		1		1.00
# stranded-kirby      		1		1		1.00
# stranded-pika       		9		7		0.78
# superboomfan-dk     		4		2		0.50
# superboomfan-falcon 		15		5		0.33
# superboomfan-fox    		3		3		1.00
# superboomfan-kirby  		34		30		0.88
# superboomfan-link   		1		1		1.00
# superboomfan-pika   		47		40		0.85
# superboomfan-yoshi  		4		3		0.75
# tacos-dk            		6		2		0.33
# tacos-falcon        		9		3		0.33
# tacos-fox           		1		0		0.00
# tacos-link          		1		0		0.00
# tacos-pika          		9		2		0.22
# tacos-puff          		1		0		0.00
# tacos-yoshi         		24		15		0.62
# thez-falcon         		1		0		0.00
# thez-fox            		5		3		0.60
# thez-kirby          		1		0		0.00
# thez-pika           		16		7		0.44
# thez-yoshi          		2		0		0.00
# wangera-puff        		18		11		0.61
# wario-pika          		13		9		0.69
# wizzrobe-pika       		1		0		0.00
# wizzrobe-yoshi      		47		18		0.38
# ybombb-falcon       		3		0		0.00
# ybombb-puff         		2		0		0.00
# ybombb-yoshi        		2		1		0.50
# zantetsu-falcon     		3		0		0.00
